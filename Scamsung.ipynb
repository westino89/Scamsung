# %% [markdown]
# **Yet another Samsung device firmware extractor. Copies output files to Google Drive, getting necessary files to root with Magisk, and provides essential device files for developers.**
#
# (Click the little ▶️ Button to run)

# %%
# !export setup_dir=$(pwd); curl -LSs https://raw.githubusercontent.com/ravindu644/Scamsung/Samsung/setup.sh | bash && bash "${setup_dir}/Scamsung/scamsung.sh"
# Out:
# Samsung Firmware Extractor 3.0 - By Ravindu Deshan
# 	Installing requirements...
#
# 	Compiling lz4...
#
#
# Requirements Installation Finished..!
# [+] Enter your Device Name :
#
# s23
# [+] Creating directories...
#
# [i] Done..!
# [i] Enter your firmware link [from samfw.com]:
#
# https://22-samfw....
# [+] Downloading firmware.zip...
#
# ######################################################################## 100.0%
# [i] Download Completed..!
# [+] Extracting the firmware Zip...
#
# Archive:  firmware.zip
#   inflating: AP_S911BXXS8CYBD_S911BXXS8CYBD_MQB93024377_REV00_user_low_ship_MULTI_CERT_meta_OS14.tar.md5
#   inflating: BL_S911BXXS8CYBD_S911BXXS8CYBD_MQB93024377_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: CP_S911BXXU8CYB4_CP29075359_MQB92281678_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: CSC_OXM_S911BOXM8CYB4_MQB92281678_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: HOME_CSC_OXM_S911BOXM8CYB4_MQB92281678_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: _FirmwareInfo_Samfw.com.txt
# boot.img.lz4
# dtbo.img.lz4
# super.img.lz4
# recovery.img.lz4
# vendor_boot.img.lz4
# vbmeta_system.img.lz4
# persist.img.lz4
# userdata.img.lz4
# misc.bin.lz4
# init_boot.img.lz4
# vm-bootsys.img.lz4
# meta-data/
# meta-data/fota.zip
# abl.elf.lz4
# bksecapp.mbn.lz4
# xbl_s.melf.lz4
# xbl_config.elf.lz4
# tz_iccc.mbn.lz4
# tz.mbn.lz4
# hypvm.mbn.lz4
# devcfg.mbn.lz4
# aop.mbn.lz4
# aop_devcfg.mbn.lz4
# keymint.mbn.lz4
# qupv3fw.elf.lz4
# storsec.mbn.lz4
# NON-HLOS.bin.lz4
# dspso.bin.lz4
# imagefv.elf.lz4
# uefi.elf.lz4
# uefi_sec.mbn.lz4
# shrm.elf.lz4
# cpucp.elf.lz4
# XblRamdump.elf.lz4
# sec.elf.lz4
# apdp.mbn.lz4
# vbmeta.img.lz4
# quest.fv.lz4
# testvector.fv.lz4
# QcomCate.fv.lz4
# Core_NON-HLOS.bin.lz4
# tz_hdm.mbn.lz4
# tz_kg.mbn.lz4
# vaultkeeper.mbn.lz4
# modem.bin.lz4
# DM1Q_EUR_OPENX.pit
# cache.img.lz4
# omr.img.lz4
# prism.img.lz4
# optics.img.lz4
# meta-data/
# meta-data/fota.zip
# cache.img.lz4
# prism.img.lz4
# optics.img.lz4
# meta-data/
# meta-data/download-list.txt
#
# [i]Zip Extraction Completed..!
#
#
# [i]Decompressing LZ4 files...

# %%
# !export setup_dir=$(pwd); curl -LSs https://raw.githubusercontent.com/ravindu644/Scamsung/Samsung/setup.sh | bash && bash "${setup_dir}/Scamsung/scamsung.sh"
# Out:
# Samsung Firmware Extractor 3.0 - By Ravindu Deshan
# 	Installing requirements...
#
# 	Compiling lz4...
#
#
# Requirements Installation Finished..!
# [+] Enter your Device Name :
#
# s23
# [+] Creating directories...
#
# [i] Done..!
# [i] Enter your firmware link [from samfw.com]:
#
# https://22-samfw....
# [+] Downloading firmware.zip...
#
# ######################################################################## 100.0%
# [i] Download Completed..!
# [+] Extracting the firmware Zip...
#
# Archive:  firmware.zip
#   inflating: AP_S911BXXS8CYBD_S911BXXS8CYBD_MQB93024377_REV00_user_low_ship_MULTI_CERT_meta_OS14.tar.md5
#   inflating: BL_S911BXXS8CYBD_S911BXXS8CYBD_MQB93024377_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: CP_S911BXXU8CYB4_CP29075359_MQB92281678_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: CSC_OXM_S911BOXM8CYB4_MQB92281678_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: HOME_CSC_OXM_S911BOXM8CYB4_MQB92281678_REV00_user_low_ship_MULTI_CERT.tar.md5
#   inflating: _FirmwareInfo_Samfw.com.txt
# boot.img.lz4
# dtbo.img.lz4
# super.img.lz4
# recovery.img.lz4
# vendor_boot.img.lz4
# vbmeta_system.img.lz4
# persist.img.lz4
# userdata.img.lz4
# misc.bin.lz4
# init_boot.img.lz4
# vm-bootsys.img.lz4
# meta-data/
# meta-data/fota.zip
# abl.elf.lz4
# bksecapp.mbn.lz4
# xbl_s.melf.lz4
# xbl_config.elf.lz4
# tz_iccc.mbn.lz4
# tz.mbn.lz4
# hypvm.mbn.lz4
# devcfg.mbn.lz4
# aop.mbn.lz4
# aop_devcfg.mbn.lz4
# keymint.mbn.lz4
# qupv3fw.elf.lz4
# storsec.mbn.lz4
# NON-HLOS.bin.lz4
# dspso.bin.lz4
# imagefv.elf.lz4
# uefi.elf.lz4
# uefi_sec.mbn.lz4
# shrm.elf.lz4
# cpucp.elf.lz4
# XblRamdump.elf.lz4
# sec.elf.lz4
# apdp.mbn.lz4
# vbmeta.img.lz4
# quest.fv.lz4
# testvector.fv.lz4
# QcomCate.fv.lz4
# Core_NON-HLOS.bin.lz4
# tz_hdm.mbn.lz4
# tz_kg.mbn.lz4
# vaultkeeper.mbn.lz4
# modem.bin.lz4
# DM1Q_EUR_OPENX.pit
# cache.img.lz4
# omr.img.lz4
# prism.img.lz4
# optics.img.lz4
# meta-data/
# meta-data/fota.zip
# cache.img.lz4
# prism.img.lz4
# optics.img.lz4
# meta-data/
# meta-data/download-list.txt
#
# [i]Zip Extraction Completed..!
#
#
# [i]Decompressing LZ4 files...

# %% [markdown]
# **Mounting the Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Copying the Output files to your Google Drive**

# %%
# !cp -r output /content/drive/MyDrive
